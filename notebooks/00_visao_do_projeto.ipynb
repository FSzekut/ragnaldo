# %% [markdown]
# # 00 — Visão do projeto RAGnaldo
#
# Este notebook apresenta o problema, as hipóteses e o plano experimental do RAGnaldo. Ele é o ponto de entrada da jornada de aprendizado.

# %% [markdown]
# ## Objetivo
#
# Construir um agente útil e bem-humorado sobre o ONE AI for Tech e o Tech Builder, capaz de explicar também sua própria arquitetura com respostas fundamentadas em documentos.

# %% [markdown]
# ## Hipóteses iniciais
#
# 1. Embeddings locais multilíngues são suficientes para o corpus em português.
# 2. Pré-calcular o índice reduz custo e tempo de inicialização.
# 3. Lazy loading permite exibir rapidamente a interface antes de carregar o modelo.
# 4. Exibir fonte e página aumenta a confiança e facilita a avaliação.
# 5. Um corpus sobre o próprio programa e projeto é mais útil que um caso fictício genérico.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PROJECT_ROOT
